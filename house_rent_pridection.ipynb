# %%
# %pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (2.4.0)
# Requirement already satisfied: pandas in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the data set
data = pd.read_csv("House_Rent_Dataset.csv")

# %%
data.tail()
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4741  2022-05-18    2  15000  1000    3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000    1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4741          Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742  Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner

# %%
data.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
data.shape
# Out:
# (4746, 12)

# %%
data.sample(7)
# Out:
#        Posted On  BHK   Rent  Size       Floor    Area Type  \
# 4159  2022-05-06    2  12000  1150  2 out of 5   Super Area
# 2978  2022-05-21    1   9000   100  1 out of 1   Super Area
# 4037  2022-05-06    2  10000  1090  2 out of 4   Super Area
# 1749  2022-05-27    1   5500   600  1 out of 2   Super Area
# 3723  2022-05-20    3  45000  1500  1 out of 3   Super Area
# 249   2022-06-27    3   3200   800  1 out of 3  Carpet Area
# 4361  2022-06-30    2  12000   933  2 out of 5   Super Area
#
#                        Area Locality       City Furnishing Status  \
# 4159                        Nizampet  Hyderabad    Semi-Furnished
# 2978    Shiva Enclave, Paschim Vihar      Delhi         Furnished
# 4037  Hyder Shah Kote, Chevella Road  Hyderabad       Unfurnished
# 1749   Chikkana Layout, Kammanahalli  Bangalore       Unfurnished
# 3723                       CIT Nagar    Chennai    Semi-Furnished
# 249                       Bhawanipur    Kolkata         Furnished
# 4361                        Kompally  Hyderabad       Unfurnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 4159  Bachelors/Family         2    Contact Owner
# 2978  Bachelors/Family         1    Contact Owner
# 4037  Bachelors/Family         2    Contact Owner
# 1749         Bachelors         1    Contact Owner
# 3723  Bachelors/Family         2    Contact Owner
# 249   Bachelors/Family         2    Contact Owner
# 4361         Bachelors         2    Contact Owner

# %%
data.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner
#
# [4746 rows x 12 columns]>

# %%
data.describe(include="object")
# Out:
#          Posted On       Floor   Area Type Area Locality    City  \
# count         4746        4746        4746          4746    4746
# unique          81         480           3          2235       6
# top     2022-07-06  1 out of 2  Super Area   Bandra West  Mumbai
# freq           311         379        2446            37     972
#
#        Furnishing Status  Tenant Preferred Point of Contact
# count               4746              4746             4746
# unique                 3                 3                3
# top       Semi-Furnished  Bachelors/Family    Contact Owner
# freq                2251              3444             3216

# %%
data.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data = data.drop(['Posted On', 'Floor', "Area Locality"],axis=1)

# %%
data.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'Area Type', 'City', 'Furnishing Status',
#        'Tenant Preferred', 'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
data.shape
# Out:
# (4746, 9)

# %%
#scatter plt
plt.figure(figsize=(10, 16))

# %%
#scatter plt
plt.figure(figsize=(10,16))
sns.scatterplot(x= "Rent", y = "BHK", hue="City", data = data)
plt.title("syamalaaaaa PLOTS ", color = "blue")
plt.show()

# %%
plt.figure(figsize=(10,16))
sns.scatterplot(x= "Rent", y = "Size", hue="City", data = data)
plt.title("Syamalaaa PLOTS ", color = "blue")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn. model_selection import train_test_split

# %%
categorical_cols = data.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index(['Area Type', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Point of Contact'],
#       dtype='object')

# %%
for col in categorical_cols:
    print(f"{col} : {data[col].nunique()}")
# Out:
# Area Type : 3
# City : 6
# Furnishing Status : 3
# Tenant Preferred : 3
# Point of Contact : 3

# %%
x = data.drop(columns = "Rent")
y = data["Rent"]

# %%
x.head()
# Out:
#    BHK  Size    Area Type     City Furnishing Status  Tenant Preferred  \
# 0    2  1100   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 1    2   800   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 2    2  1000   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 3    2   800   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 4    2   850  Carpet Area  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
#encoder LeaveOnehotencoder
# %pip install category-encoders
# Out:
# Requirement already satisfied: category-encoders in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (2.9.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from category-encoders) (2.4.0)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from category-encoders) (2.3.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from category-encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from category-encoders) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from category-encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from category-encoders) (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from pandas>=1.0.5->category-encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from pandas>=1.0.5->category-encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from pandas>=1.0.5->category-encoders) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category-encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from scikit-learn>=1.6.0->category-encoders) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from scikit-learn>=1.6.0->category-encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\velama.syamala\onedrive\desktop\house rent pedic\.venv\lib\site-packages (from statsmodels>=0.9.0->category-encoders) (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#encoder LeaveOnehotencoder
import category_encoders as ce 
encoder = ce.LeaveOneOutEncoder(return_df=True)
x = encoder.fit_transform(x , y)

# %%
x.head()
# Out:
#    BHK  Size     Area Type          City  Furnishing Status  Tenant Preferred  \
# 0    2  1100  18676.943967  11648.319312       22468.505513      31216.953238
# 1    2   800  18672.853988  11629.198853       38727.130222      31214.048795
# 2    2  1000  18674.080982  11634.934990       38728.463556      31214.920128
# 3    2   800  18676.943967  11648.319312       22468.505513      31216.953238
# 4    2   850  52405.438398  11653.099426       22469.883682      42185.583836
#
#    Bathroom  Point of Contact
# 0         2      16706.291757
# 1         1      16703.181337
# 2         1      16704.114463
# 3         1      16706.291757
# 4         1      16707.069362

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x_df = pd.DataFrame(x)

# %%
x_train, x_test, y_train , y_test = train_test_split(x,y, test_size = 0.2, random_state=42)

# %%
x_train.shape, y_test.shape
# Out:
# ((3796, 8), (950,))

# %%
x_test.shape, y_test.shape
# Out:
# ((950, 8), (950,))

# %%
model_rfr = RandomForestRegressor()
model_dt = DecisionTreeRegressor()
model_lr = LinearRegression()
#model_xgb = XGBRegressor(Objective = "reg : squarederror")

models = [model_rfr, model_dt, model_lr]

# %%
#fitting data in all three models
for model in models:

    print(f"Training {model}")
    model.fit(x_train, y_train)
# Out:
# Training RandomForestRegressor()
# Training DecisionTreeRegressor()
# Training LinearRegression()

# %%
for model in models:
    print(f"score of {model} is : {model.score(x_test, y_test)}")
# Out:
# score of RandomForestRegressor() is : 0.9406764550754461
# score of DecisionTreeRegressor() is : 0.937413772951468
# score of LinearRegression() is : 0.5153586519637792

# %%
new_data = pd.DataFrame({
    "BHK": [3],
    "Size": [1500],
    "Area Type": ["Super Area"],
    "City": ["Kolkata"],
    "Furnishing Status": ["Furnished"],
    "Tenant Preferred": ["Family"],
    "Bathroom": [2],
    "Point of Contact": ["Contact Owner"]
})
new_data_encoded = encoder.transform(new_data)
new_data_scaled = scaler.transform(new_data_encoded)
predicted_rent = model_rfr.predict(new_data_scaled)

print("Predicted Rent:", predicted_rent[0])
# Out:
# Predicted Rent: 16520.0

# %%
# Encode new data
new_data_encoder = encoder.transform(new_data)

# Scale new data
new_data_scaled = scaler.transform(new_data_encoder)

# Predict rent
predicted_rent = model_rfr.predict(new_data_scaled)

# Output
print(f"The predicted Rent for the new data is: {predicted_rent[0]}")
# Out:
# The predicted Rent for the new data is: 60275.0

# %%
import pickle

#save model
pickle.dump(model_rfr, open("rent_model.pkl", "wb"))

#save encoder
pickle.dump(encoder, open('encoder.pkl', "wb"))

#save scaler
pickle.dump(scaler, open("scaler.pkl", "wb"))

print(" Model, encoder & scaler saved succesfully")
# Out:
#  Model, encoder & scaler saved succesfully
